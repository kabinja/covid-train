# %%
# %load_ext autoreload 
# %autoreload 2

import os
import tensorflow as tf
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext

context = InteractiveContext()

_root = os.getcwd()
_data_root = os.path.join(_root, 'data')
_module_file = os.path.join(_root, 'covid_train_utils.py')
_saved_models = os.path.join(_root, os.pardir, os.pardir, 'saved_models')
# Out:
# WARNING:root:TensorFlow Decision Forests 0.2.3 is compatible with the following TensorFlow Versions: ['2.7.0']. However, TensorFlow 2.7.1 was detected. This can cause issues with the TF API and symbols in the custom C++ ops. See the TF and TF-DF compatibility table at https://github.com/tensorflow/decision-forests/blob/main/documentation/known_issues.md#compatibility-table.
# WARNING:root:TF Parameter Server distributed training not available (this is expected for the pre-build release).
# WARNING:absl:InteractiveContext pipeline_root argument not provided: using temporary directory /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6 as root for pipeline outputs.
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/metadata.sqlite.

# %%
from tfx.components import CsvExampleGen

example_gen = CsvExampleGen(input_base=_data_root)

context.run(example_gen)
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 1
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 1
#         type_id: 14
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/CsvExampleGen/examples/1"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "file_format"
#           value {
#             string_value: "tfrecords_gzip"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:12294672,xor_checksum:1645433300,sum_checksum:1645433300"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             int_value: 0
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 14
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         base_type: DATASET
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
from tfx.components import StatisticsGen

statistics_gen = StatisticsGen(examples=example_gen.outputs['examples'])

context.run(statistics_gen)
context.show(statistics_gen.outputs['statistics'])
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# <b>Artifact at /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/StatisticsGen/statistics/2</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'eval' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
from tfx.components import SchemaGen
schema_gen = SchemaGen(
statistics=statistics_gen.outputs['statistics'],
infer_feature_shape=True)
context.run(schema_gen)
context.show(schema_gen.outputs['schema'])
# Out:
# <b>Artifact at /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/SchemaGen/schema/3</b><br/><br/>
#                                     Type  Presence Valency         Domain
# Feature name
# 'CountryName'                     STRING  required          'CountryName'
# 'Date'                             BYTES  required                      -
# 'region'                          STRING  required               'region'
# 'R'                                FLOAT  required                      -
# 'area'                             FLOAT  required                      -
# 'demographic'                        INT  required                      -
# 'density'                            INT  required                      -
# 'gdp'                              FLOAT  required                      -
# 'grocery/pharmacy'                 FLOAT  required                      -
# 'grocery/pharmacy_10days'          FLOAT  required                      -
# 'grocery/pharmacy_15days'          FLOAT  required                      -
# 'grocery/pharmacy_30days'          FLOAT  required                      -
# 'grocery/pharmacy_5days'           FLOAT  required                      -
# 'international_transport'          FLOAT  required                      -
# 'international_transport_10days'   FLOAT  required                      -
# 'international_transport_15days'   FLOAT  required                      -
# 'international_transport_30days'   FLOAT  required                      -
# 'international_transport_5days'    FLOAT  required                      -
# 'parks'                            FLOAT  required                      -
# 'parks_10days'                     FLOAT  required                      -
# 'parks_15days'                     FLOAT  required                      -
# 'parks_30days'                     FLOAT  required                      -
# 'parks_5days'                      FLOAT  required                      -
# 'population_p14'                     INT  required                      -
# 'population_p65'                     INT  required                      -
# 'public_transport'                 FLOAT  required                      -
# 'public_transport_10days'          FLOAT  required                      -
# 'public_transport_15days'          FLOAT  required                      -
# 'public_transport_30days'          FLOAT  required                      -
# 'public_transport_5days'           FLOAT  required                      -
# 'residential'                      FLOAT  required                      -
# 'residential_10days'               FLOAT  required                      -
# 'residential_15days'               FLOAT  required                      -
# 'residential_30days'               FLOAT  required                      -
# 'residential_5days'                FLOAT  required                      -
# 'retail/recreation'                FLOAT  required                      -
# 'retail/recreation_10days'         FLOAT  required                      -
# 'retail/recreation_15days'         FLOAT  required                      -
# 'retail/recreation_30days'         FLOAT  required                      -
# 'retail/recreation_5days'          FLOAT  required                      -
# 'school'                           FLOAT  required                      -
# 'school_10days'                    FLOAT  required                      -
# 'school_15days'                    FLOAT  required                      -
# 'school_30days'                    FLOAT  required                      -
# 'school_5days'                     FLOAT  required                      -
# 'transit_stations'                 FLOAT  required                      -
# 'transit_stations_10days'          FLOAT  required                      -
# 'transit_stations_15days'          FLOAT  required                      -
# 'transit_stations_30days'          FLOAT  required                      -
# 'transit_stations_5days'           FLOAT  required                      -
# 'workplace'                        FLOAT  required                      -
# 'workplace_10days'                 FLOAT  required                      -
# 'workplace_15days'                 FLOAT  required                      -
# 'workplace_30days'                 FLOAT  required                      -
# 'workplace_5days'                  FLOAT  required                      -
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Values
# Domain
# 'CountryName'  'Angola', 'Argentina', 'Austria', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bolivia', 'Botswana', 'Brazil', 'Bulgaria', 'Burkina Faso', 'Cameroon', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Denmark', 'Dominican Republic', 'Ecuador', 'El Salvador', 'Estonia', 'Finland', 'Gabon', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala', 'Haiti', 'Honduras', 'Hungary', 'India', 'Indonesia', 'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kuwait', 'Latvia', 'Lebanon', 'Libya', 'Lithuania', 'Luxembourg', 'Malaysia', 'Mali', 'Mauritius', 'Mexico', 'Moldova', 'Morocco', 'Mozambique', 'Namibia', 'Nepal', 'Netherlands', 'New Zealand', 'Niger', 'Nigeria', 'Norway', 'Oman', 'Pakistan', 'Panama', 'Paraguay', 'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Rwanda', 'Saudi Arabia', 'Senegal', 'Serbia', 'Singapore', 'Slovenia', 'South Africa', 'Spain', 'Sri Lanka', 'Switzerland', 'Togo', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'Uruguay', 'Vietnam', 'Zambia', 'Zimbabwe'
# 'region'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              'ASIA (EX. NEAR EAST)', 'BALTICS', 'C.W. OF IND. STATES', 'EASTERN EUROPE', 'LATIN AMER. & CARIB', 'NEAR EAST', 'NORTHERN AFRICA', 'OCEANIA', 'SUB-SAHARAN AFRICA', 'WESTERN EUROPE'

# %%
from tfx.components import ExampleValidator

example_validator = ExampleValidator(
    statistics=statistics_gen.outputs['statistics'],
    schema=schema_gen.outputs['schema'])

context.run(example_validator)
context.show(example_validator.outputs['anomalies'])
# Out:
# <b>Artifact at /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/ExampleValidator/anomalies/4</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>
# <div><b>'eval' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>

# %%
from tfx.components import Transform

transform = Transform(
examples=example_gen.outputs['examples'],
schema=schema_gen.outputs['schema'],
module_file=_module_file)

context.run(transform)
# Out:
# running bdist_wheel
# running build
# running build_py
# installing to /tmp/tmpl6slil61
# running install
# running install_lib
# copying build/lib/prepare_data_utils.py -> /tmp/tmpl6slil61
# copying build/lib/covid_train_dag.py -> /tmp/tmpl6slil61
# copying build/lib/prepare_data_dag.py -> /tmp/tmpl6slil61
# copying build/lib/covid_train_utils.py -> /tmp/tmpl6slil61
# running install_egg_info
# running egg_info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# running install_scripts
# creating /tmp/tmpl6slil61/tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/WHEEL
# creating '/tmp/tmpktf699po/tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca-py3-none-any.whl' and adding '/tmp/tmpl6slil61' to it
# adding 'covid_train_dag.py'
# adding 'covid_train_utils.py'
# adding 'prepare_data_dag.py'
# adding 'prepare_data_utils.py'
# adding 'tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/RECORD'
# removing /tmp/tmpl6slil61
# /home/renaud/.cache/pypoetry/virtualenvs/covid-train-lO3GTi_V-py3.8/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Processing /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/_wheels/tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca
# Processing /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/_wheels/tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca
# Processing /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/_wheels/tfx_user_code_Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca
# 2022-02-25 14:33:50.785424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:925] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-02-25 14:33:50.795128: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-02-25 14:33:50.795149: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-02-25 14:33:50.796252: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/renaud/.cache/pypoetry/virtualenvs/covid-train-lO3GTi_V-py3.8/lib/python3.8/site-packages/tensorflow_transform/tf_utils.py:289: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /home/renaud/.cache/pypoetry/virtualenvs/covid-train-lO3GTi_V-py3.8/lib/python3.8/site-packages/tensorflow_transform/tf_utils.py:289: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[str, Union[NoneType, _Dataset]], Union[Dict[str, Dict[str, PCollection]], NoneType], int] instead.
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[str, Union[NoneType, _Dataset]], Union[Dict[str, Dict[str, PCollection]], NoneType], int] instead.
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# 2022-02-25 14:34:11.850230: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/transform_graph/5/.temp_path/tftransform_tmp/caa6d304d9a44ea2bf62d2cb77fc47a4/assets
# INFO:tensorflow:Assets written to: /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/transform_graph/5/.temp_path/tftransform_tmp/caa6d304d9a44ea2bf62d2cb77fc47a4/assets
# INFO:tensorflow:Assets written to: /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/transform_graph/5/.temp_path/tftransform_tmp/ccf68dcca33645baa912b0eff089f37f/assets
# INFO:tensorflow:Assets written to: /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/transform_graph/5/.temp_path/tftransform_tmp/ccf68dcca33645baa912b0eff089f37f/assets
# ExecutionResult(
#     component_id: Transform
#     execution_id: 5
#     outputs:
#         transform_graph: Channel(
#             type_name: TransformGraph
#             artifacts: [Artifact(artifact: id: 5
#         type_id: 22
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/transform_graph/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "transform_graph"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 22
#         name: "TransformGraph"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         transformed_examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 6
#         type_id: 14
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/transformed_examples/5"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"eval\", \"train\"]"
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "transformed_examples"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 14
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         base_type: DATASET
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         updated_analyzer_cache: Channel(
#             type_name: TransformCache
#             artifacts: [Artifact(artifact: id: 7
#         type_id: 23
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/updated_analyzer_cache/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "updated_analyzer_cache"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 23
#         name: "TransformCache"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         pre_transform_schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 8
#         type_id: 18
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/pre_transform_schema/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "pre_transform_schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "Schema"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         pre_transform_stats: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 9
#         type_id: 16
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/pre_transform_stats/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "pre_transform_stats"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 16
#         name: "ExampleStatistics"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         base_type: STATISTICS
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 10
#         type_id: 18
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/post_transform_schema/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "Schema"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_stats: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 11
#         type_id: 16
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/post_transform_stats/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_stats"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 16
#         name: "ExampleStatistics"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         base_type: STATISTICS
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_anomalies: Channel(
#             type_name: ExampleAnomalies
#             artifacts: [Artifact(artifact: id: 12
#         type_id: 20
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Transform/post_transform_anomalies/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_anomalies"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 20
#         name: "ExampleAnomalies"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
# Get the URI of the output artifact representing the transformed examples, which is a directory
train_uri = os.path.join(transform.outputs['transformed_examples'].get()[0].uri, 'Split-train')

# Get the list of files in this directory (all compressed TFRecord files)
tfrecord_filenames = [os.path.join(train_uri, name)
                      for name in os.listdir(train_uri)]

# Create a `TFRecordDataset` to read these files
dataset = tf.data.TFRecordDataset(tfrecord_filenames, compression_type="GZIP")

# Iterate over the first 3 records and decode them.
for tfrecord in dataset.take(3):
  serialized_example = tfrecord.numpy()
  example = tf.train.Example()
  example.ParseFromString(serialized_example)
  print(example)
# Out:
# features {
#   feature {
#     key: "R_mean"
#     value {
#       float_list {
#         value: 1.090763807296753
#       }
#     }
#   }
#   feature {
#     key: "R_var"
#     value {
#       float_list {
#         value: 0.1301359087228775
#       }
#     }
#   }
#   feature {
#     key: "R_xf"
#     value {
#       float_list {
#         value: -2.67714786529541
#       }
#     }
#   }
#   feature {
#     key: "area_xf"
#     value {
#       float_list {
#         value: 0.7766261100769043
#       }
#     }
#   }
#   feature {
#     key: "demographic_xf"
#     value {
#       float_list {
#         value: -0.26068729162216187
#       }
#     }
#   }
#   feature {
#     key: "density_xf"
#     value {
#       float_list {
#         value: -0.30975979566574097
#       }
#     }
#   }
#   feature {
#     key: "gdp_xf"
#     value {
#       float_list {
#         value: -0.7337654232978821
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_10days_xf"
#     value {
#       float_list {
#         value: -0.24729104340076447
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_15days_xf"
#     value {
#       float_list {
#         value: -0.2374042272567749
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_30days_xf"
#     value {
#       float_list {
#         value: -0.41733965277671814
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_5days_xf"
#     value {
#       float_list {
#         value: -0.2663668990135193
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_xf"
#     value {
#       float_list {
#         value: -0.35648608207702637
#       }
#     }
#   }
#   feature {
#     key: "international_transport_10days_xf"
#     value {
#       float_list {
#         value: -0.9361029267311096
#       }
#     }
#   }
#   feature {
#     key: "international_transport_15days_xf"
#     value {
#       float_list {
#         value: -0.9449971914291382
#       }
#     }
#   }
#   feature {
#     key: "international_transport_30days_xf"
#     value {
#       float_list {
#         value: -0.979081392288208
#       }
#     }
#   }
#   feature {
#     key: "international_transport_5days_xf"
#     value {
#       float_list {
#         value: -0.9275843501091003
#       }
#     }
#   }
#   feature {
#     key: "international_transport_xf"
#     value {
#       float_list {
#         value: -0.9205010533332825
#       }
#     }
#   }
#   feature {
#     key: "parks_10days_xf"
#     value {
#       float_list {
#         value: -0.3042573630809784
#       }
#     }
#   }
#   feature {
#     key: "parks_15days_xf"
#     value {
#       float_list {
#         value: -0.31167736649513245
#       }
#     }
#   }
#   feature {
#     key: "parks_30days_xf"
#     value {
#       float_list {
#         value: -0.42135217785835266
#       }
#     }
#   }
#   feature {
#     key: "parks_5days_xf"
#     value {
#       float_list {
#         value: -0.27264848351478577
#       }
#     }
#   }
#   feature {
#     key: "parks_xf"
#     value {
#       float_list {
#         value: -0.24244070053100586
#       }
#     }
#   }
#   feature {
#     key: "population_p14_xf"
#     value {
#       float_list {
#         value: 1.9808369874954224
#       }
#     }
#   }
#   feature {
#     key: "population_p65_xf"
#     value {
#       float_list {
#         value: -0.9444440603256226
#       }
#     }
#   }
#   feature {
#     key: "public_transport_10days_xf"
#     value {
#       float_list {
#         value: -0.18092691898345947
#       }
#     }
#   }
#   feature {
#     key: "public_transport_15days_xf"
#     value {
#       float_list {
#         value: -0.19370503723621368
#       }
#     }
#   }
#   feature {
#     key: "public_transport_30days_xf"
#     value {
#       float_list {
#         value: -0.4071550667285919
#       }
#     }
#   }
#   feature {
#     key: "public_transport_5days_xf"
#     value {
#       float_list {
#         value: -0.1699080616235733
#       }
#     }
#   }
#   feature {
#     key: "public_transport_xf"
#     value {
#       float_list {
#         value: -0.16308964788913727
#       }
#     }
#   }
#   feature {
#     key: "region_xf"
#     value {
#       float_list {
#         value: 0.0
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "residential_10days_xf"
#     value {
#       float_list {
#         value: 0.6641051173210144
#       }
#     }
#   }
#   feature {
#     key: "residential_15days_xf"
#     value {
#       float_list {
#         value: 0.7433129549026489
#       }
#     }
#   }
#   feature {
#     key: "residential_30days_xf"
#     value {
#       float_list {
#         value: 0.9235421419143677
#       }
#     }
#   }
#   feature {
#     key: "residential_5days_xf"
#     value {
#       float_list {
#         value: 0.6619170308113098
#       }
#     }
#   }
#   feature {
#     key: "residential_xf"
#     value {
#       float_list {
#         value: 0.7888770699501038
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_10days_xf"
#     value {
#       float_list {
#         value: -0.27361810207366943
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_15days_xf"
#     value {
#       float_list {
#         value: -0.24328315258026123
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_30days_xf"
#     value {
#       float_list {
#         value: -0.4643588960170746
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_5days_xf"
#     value {
#       float_list {
#         value: -0.272227942943573
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_xf"
#     value {
#       float_list {
#         value: -0.12821882963180542
#       }
#     }
#   }
#   feature {
#     key: "school_10days_xf"
#     value {
#       float_list {
#         value: -0.6467788219451904
#       }
#     }
#   }
#   feature {
#     key: "school_15days_xf"
#     value {
#       float_list {
#         value: -0.6639637351036072
#       }
#     }
#   }
#   feature {
#     key: "school_30days_xf"
#     value {
#       float_list {
#         value: -0.7185992002487183
#       }
#     }
#   }
#   feature {
#     key: "school_5days_xf"
#     value {
#       float_list {
#         value: -0.6321335434913635
#       }
#     }
#   }
#   feature {
#     key: "school_xf"
#     value {
#       float_list {
#         value: -0.621834397315979
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_10days_xf"
#     value {
#       float_list {
#         value: -0.5597125291824341
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_15days_xf"
#     value {
#       float_list {
#         value: -0.582696795463562
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_30days_xf"
#     value {
#       float_list {
#         value: -0.8058387041091919
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_5days_xf"
#     value {
#       float_list {
#         value: -0.49886444211006165
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_xf"
#     value {
#       float_list {
#         value: -0.5301984548568726
#       }
#     }
#   }
#   feature {
#     key: "workplace_10days_xf"
#     value {
#       float_list {
#         value: 0.559381902217865
#       }
#     }
#   }
#   feature {
#     key: "workplace_15days_xf"
#     value {
#       float_list {
#         value: 0.32547980546951294
#       }
#     }
#   }
#   feature {
#     key: "workplace_30days_xf"
#     value {
#       float_list {
#         value: -0.02754378505051136
#       }
#     }
#   }
#   feature {
#     key: "workplace_5days_xf"
#     value {
#       float_list {
#         value: 0.5706915855407715
#       }
#     }
#   }
#   feature {
#     key: "workplace_xf"
#     value {
#       float_list {
#         value: 0.16230958700180054
#       }
#     }
#   }
# }
#
# features {
#   feature {
#     key: "R_mean"
#     value {
#       float_list {
#         value: 1.090763807296753
#       }
#     }
#   }
#   feature {
#     key: "R_var"
#     value {
#       float_list {
#         value: 0.1301359087228775
#       }
#     }
#   }
#   feature {
#     key: "R_xf"
#     value {
#       float_list {
#         value: -2.5246849060058594
#       }
#     }
#   }
#   feature {
#     key: "area_xf"
#     value {
#       float_list {
#         value: 0.7766261100769043
#       }
#     }
#   }
#   feature {
#     key: "demographic_xf"
#     value {
#       float_list {
#         value: -0.26068729162216187
#       }
#     }
#   }
#   feature {
#     key: "density_xf"
#     value {
#       float_list {
#         value: -0.30975979566574097
#       }
#     }
#   }
#   feature {
#     key: "gdp_xf"
#     value {
#       float_list {
#         value: -0.7337654232978821
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_10days_xf"
#     value {
#       float_list {
#         value: -0.291640043258667
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_15days_xf"
#     value {
#       float_list {
#         value: -0.22070014476776123
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_30days_xf"
#     value {
#       float_list {
#         value: -0.38054338097572327
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_5days_xf"
#     value {
#       float_list {
#         value: -0.2856314778327942
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_xf"
#     value {
#       float_list {
#         value: -0.22446030378341675
#       }
#     }
#   }
#   feature {
#     key: "international_transport_10days_xf"
#     value {
#       float_list {
#         value: -0.9361029267311096
#       }
#     }
#   }
#   feature {
#     key: "international_transport_15days_xf"
#     value {
#       float_list {
#         value: -0.9449971914291382
#       }
#     }
#   }
#   feature {
#     key: "international_transport_30days_xf"
#     value {
#       float_list {
#         value: -0.979081392288208
#       }
#     }
#   }
#   feature {
#     key: "international_transport_5days_xf"
#     value {
#       float_list {
#         value: -0.9275843501091003
#       }
#     }
#   }
#   feature {
#     key: "international_transport_xf"
#     value {
#       float_list {
#         value: -0.9205010533332825
#       }
#     }
#   }
#   feature {
#     key: "parks_10days_xf"
#     value {
#       float_list {
#         value: -0.3158687949180603
#       }
#     }
#   }
#   feature {
#     key: "parks_15days_xf"
#     value {
#       float_list {
#         value: -0.31167736649513245
#       }
#     }
#   }
#   feature {
#     key: "parks_30days_xf"
#     value {
#       float_list {
#         value: -0.4029282033443451
#       }
#     }
#   }
#   feature {
#     key: "parks_5days_xf"
#     value {
#       float_list {
#         value: -0.3048865497112274
#       }
#     }
#   }
#   feature {
#     key: "parks_xf"
#     value {
#       float_list {
#         value: -0.2872503697872162
#       }
#     }
#   }
#   feature {
#     key: "population_p14_xf"
#     value {
#       float_list {
#         value: 1.9808369874954224
#       }
#     }
#   }
#   feature {
#     key: "population_p65_xf"
#     value {
#       float_list {
#         value: -0.9444440603256226
#       }
#     }
#   }
#   feature {
#     key: "public_transport_10days_xf"
#     value {
#       float_list {
#         value: -0.18092691898345947
#       }
#     }
#   }
#   feature {
#     key: "public_transport_15days_xf"
#     value {
#       float_list {
#         value: -0.19370503723621368
#       }
#     }
#   }
#   feature {
#     key: "public_transport_30days_xf"
#     value {
#       float_list {
#         value: -0.3639030158519745
#       }
#     }
#   }
#   feature {
#     key: "public_transport_5days_xf"
#     value {
#       float_list {
#         value: -0.1699080616235733
#       }
#     }
#   }
#   feature {
#     key: "public_transport_xf"
#     value {
#       float_list {
#         value: -0.16308964788913727
#       }
#     }
#   }
#   feature {
#     key: "region_xf"
#     value {
#       float_list {
#         value: 0.0
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "residential_10days_xf"
#     value {
#       float_list {
#         value: 0.705657422542572
#       }
#     }
#   }
#   feature {
#     key: "residential_15days_xf"
#     value {
#       float_list {
#         value: 0.7293517589569092
#       }
#     }
#   }
#   feature {
#     key: "residential_30days_xf"
#     value {
#       float_list {
#         value: 0.9199356436729431
#       }
#     }
#   }
#   feature {
#     key: "residential_5days_xf"
#     value {
#       float_list {
#         value: 0.7031767964363098
#       }
#     }
#   }
#   feature {
#     key: "residential_xf"
#     value {
#       float_list {
#         value: 0.6898958086967468
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_10days_xf"
#     value {
#       float_list {
#         value: -0.2696288228034973
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_15days_xf"
#     value {
#       float_list {
#         value: -0.23524396121501923
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_30days_xf"
#     value {
#       float_list {
#         value: -0.42416295409202576
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_5days_xf"
#     value {
#       float_list {
#         value: -0.2801492512226105
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_xf"
#     value {
#       float_list {
#         value: -0.08977120369672775
#       }
#     }
#   }
#   feature {
#     key: "school_10days_xf"
#     value {
#       float_list {
#         value: -0.6467788219451904
#       }
#     }
#   }
#   feature {
#     key: "school_15days_xf"
#     value {
#       float_list {
#         value: -0.6639637351036072
#       }
#     }
#   }
#   feature {
#     key: "school_30days_xf"
#     value {
#       float_list {
#         value: -0.7185992002487183
#       }
#     }
#   }
#   feature {
#     key: "school_5days_xf"
#     value {
#       float_list {
#         value: -0.6321335434913635
#       }
#     }
#   }
#   feature {
#     key: "school_xf"
#     value {
#       float_list {
#         value: -0.621834397315979
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_10days_xf"
#     value {
#       float_list {
#         value: -0.5848540663719177
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_15days_xf"
#     value {
#       float_list {
#         value: -0.5630038976669312
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_30days_xf"
#     value {
#       float_list {
#         value: -0.7753520011901855
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_5days_xf"
#     value {
#       float_list {
#         value: -0.5238330364227295
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_xf"
#     value {
#       float_list {
#         value: -0.44911518692970276
#       }
#     }
#   }
#   feature {
#     key: "workplace_10days_xf"
#     value {
#       float_list {
#         value: 0.43630486726760864
#       }
#     }
#   }
#   feature {
#     key: "workplace_15days_xf"
#     value {
#       float_list {
#         value: 0.3368073105812073
#       }
#     }
#   }
#   feature {
#     key: "workplace_30days_xf"
#     value {
#       float_list {
#         value: -0.04513154178857803
#       }
#     }
#   }
#   feature {
#     key: "workplace_5days_xf"
#     value {
#       float_list {
#         value: 0.5816753506660461
#       }
#     }
#   }
#   feature {
#     key: "workplace_xf"
#     value {
#       float_list {
#         value: 0.06428194046020508
#       }
#     }
#   }
# }
#
# features {
#   feature {
#     key: "R_mean"
#     value {
#       float_list {
#         value: 1.090763807296753
#       }
#     }
#   }
#   feature {
#     key: "R_var"
#     value {
#       float_list {
#         value: 0.1301359087228775
#       }
#     }
#   }
#   feature {
#     key: "R_xf"
#     value {
#       float_list {
#         value: -0.6581696271896362
#       }
#     }
#   }
#   feature {
#     key: "area_xf"
#     value {
#       float_list {
#         value: 0.7766261100769043
#       }
#     }
#   }
#   feature {
#     key: "demographic_xf"
#     value {
#       float_list {
#         value: -0.26068729162216187
#       }
#     }
#   }
#   feature {
#     key: "density_xf"
#     value {
#       float_list {
#         value: -0.30975979566574097
#       }
#     }
#   }
#   feature {
#     key: "gdp_xf"
#     value {
#       float_list {
#         value: -0.7337654232978821
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_10days_xf"
#     value {
#       float_list {
#         value: -0.24729104340076447
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_15days_xf"
#     value {
#       float_list {
#         value: -0.2307226061820984
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_30days_xf"
#     value {
#       float_list {
#         value: -0.32447269558906555
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_5days_xf"
#     value {
#       float_list {
#         value: -0.34342527389526367
#       }
#     }
#   }
#   feature {
#     key: "grocery/pharmacy_xf"
#     value {
#       float_list {
#         value: -0.18045170605182648
#       }
#     }
#   }
#   feature {
#     key: "international_transport_10days_xf"
#     value {
#       float_list {
#         value: -0.9361029267311096
#       }
#     }
#   }
#   feature {
#     key: "international_transport_15days_xf"
#     value {
#       float_list {
#         value: -0.9449971914291382
#       }
#     }
#   }
#   feature {
#     key: "international_transport_30days_xf"
#     value {
#       float_list {
#         value: -0.979081392288208
#       }
#     }
#   }
#   feature {
#     key: "international_transport_5days_xf"
#     value {
#       float_list {
#         value: -0.9275843501091003
#       }
#     }
#   }
#   feature {
#     key: "international_transport_xf"
#     value {
#       float_list {
#         value: -0.9205010533332825
#       }
#     }
#   }
#   feature {
#     key: "parks_10days_xf"
#     value {
#       float_list {
#         value: -0.2671006917953491
#       }
#     }
#   }
#   feature {
#     key: "parks_15days_xf"
#     value {
#       float_list {
#         value: -0.2929554581642151
#       }
#     }
#   }
#   feature {
#     key: "parks_30days_xf"
#     value {
#       float_list {
#         value: -0.3748917579650879
#       }
#     }
#   }
#   feature {
#     key: "parks_5days_xf"
#     value {
#       float_list {
#         value: -0.30949199199676514
#       }
#     }
#   }
#   feature {
#     key: "parks_xf"
#     value {
#       float_list {
#         value: -0.0856068953871727
#       }
#     }
#   }
#   feature {
#     key: "population_p14_xf"
#     value {
#       float_list {
#         value: 1.9808369874954224
#       }
#     }
#   }
#   feature {
#     key: "population_p65_xf"
#     value {
#       float_list {
#         value: -0.9444440603256226
#       }
#     }
#   }
#   feature {
#     key: "public_transport_10days_xf"
#     value {
#       float_list {
#         value: -0.18092691898345947
#       }
#     }
#   }
#   feature {
#     key: "public_transport_15days_xf"
#     value {
#       float_list {
#         value: -0.19370503723621368
#       }
#     }
#   }
#   feature {
#     key: "public_transport_30days_xf"
#     value {
#       float_list {
#         value: -0.27739906311035156
#       }
#     }
#   }
#   feature {
#     key: "public_transport_5days_xf"
#     value {
#       float_list {
#         value: -0.1699080616235733
#       }
#     }
#   }
#   feature {
#     key: "public_transport_xf"
#     value {
#       float_list {
#         value: -0.16308964788913727
#       }
#     }
#   }
#   feature {
#     key: "region_xf"
#     value {
#       float_list {
#         value: 0.0
#         value: 1.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#       }
#     }
#   }
#   feature {
#     key: "residential_10days_xf"
#     value {
#       float_list {
#         value: 0.7160453200340271
#       }
#     }
#   }
#   feature {
#     key: "residential_15days_xf"
#     value {
#       float_list {
#         value: 0.7293517589569092
#       }
#     }
#   }
#   feature {
#     key: "residential_30days_xf"
#     value {
#       float_list {
#         value: 0.8694437146186829
#       }
#     }
#   }
#   feature {
#     key: "residential_5days_xf"
#     value {
#       float_list {
#         value: 0.7238067984580994
#       }
#     }
#   }
#   feature {
#     key: "residential_xf"
#     value {
#       float_list {
#         value: 0.6898958086967468
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_10days_xf"
#     value {
#       float_list {
#         value: -0.1978236585855484
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_15days_xf"
#     value {
#       float_list {
#         value: -0.24328315258026123
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_30days_xf"
#     value {
#       float_list {
#         value: -0.3714922368526459
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_5days_xf"
#     value {
#       float_list {
#         value: -0.2563849985599518
#       }
#     }
#   }
#   feature {
#     key: "retail/recreation_xf"
#     value {
#       float_list {
#         value: -0.08977120369672775
#       }
#     }
#   }
#   feature {
#     key: "school_10days_xf"
#     value {
#       float_list {
#         value: -0.6467788219451904
#       }
#     }
#   }
#   feature {
#     key: "school_15days_xf"
#     value {
#       float_list {
#         value: -0.6639637351036072
#       }
#     }
#   }
#   feature {
#     key: "school_30days_xf"
#     value {
#       float_list {
#         value: -0.7185992002487183
#       }
#     }
#   }
#   feature {
#     key: "school_5days_xf"
#     value {
#       float_list {
#         value: -0.6321335434913635
#       }
#     }
#   }
#   feature {
#     key: "school_xf"
#     value {
#       float_list {
#         value: -0.621834397315979
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_10days_xf"
#     value {
#       float_list {
#         value: -0.5471417903900146
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_15days_xf"
#     value {
#       float_list {
#         value: -0.5714437365531921
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_30days_xf"
#     value {
#       float_list {
#         value: -0.7317996621131897
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_5days_xf"
#     value {
#       float_list {
#         value: -0.6237067580223083
#       }
#     }
#   }
#   feature {
#     key: "transit_stations_xf"
#     value {
#       float_list {
#         value: -0.48965680599212646
#       }
#     }
#   }
#   feature {
#     key: "workplace_10days_xf"
#     value {
#       float_list {
#         value: 0.30203911662101746
#       }
#     }
#   }
#   feature {
#     key: "workplace_15days_xf"
#     value {
#       float_list {
#         value: 0.37078967690467834
#       }
#     }
#   }
#   feature {
#     key: "workplace_30days_xf"
#     value {
#       float_list {
#         value: 0.04085318744182587
#       }
#     }
#   }
#   feature {
#     key: "workplace_5days_xf"
#     value {
#       float_list {
#         value: 0.32904738187789917
#       }
#     }
#   }
#   feature {
#     key: "workplace_xf"
#     value {
#       float_list {
#         value: 0.06428194046020508
#       }
#     }
#   }
# }

# %%
from tfx.components import Tuner
from tfx.proto import trainer_pb2

tuner = Tuner(
    module_file=_module_file,
    examples=transform.outputs['transformed_examples'],
    transform_graph=transform.outputs['transform_graph'],
    train_args=trainer_pb2.TrainArgs(num_steps=20),
    eval_args=trainer_pb2.EvalArgs(num_steps=5)
)

context.run(tuner)
# Out:
# Trial 8 Complete [00h 00m 01s]
# mean_squared_error: 5.470162868499756
#
# Best mean_squared_error So Far: 0.8047859072685242
# Total elapsed time: 00h 00m 10s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/.temp/6/covid_tuning
# Showing 10 best trials
# Objective(name='mean_squared_error', direction='min')
# Trial summary
# Hyperparameters:
# hidden_layers: 50, 500, 50
# learning_rate: 0.0001
# Score: 0.8047859072685242
# Trial summary
# Hyperparameters:
# hidden_layers: 1000, 50
# learning_rate: 0.0001
# Score: 0.8321838974952698
# Trial summary
# Hyperparameters:
# hidden_layers: 50, 100, 100
# learning_rate: 0.0001
# Score: 0.9018064141273499
# Trial summary
# Hyperparameters:
# hidden_layers: 50, 100, 50
# learning_rate: 0.0001
# Score: 1.2701359987258911
# Trial summary
# Hyperparameters:
# hidden_layers: 50, 100, 50
# learning_rate: 0.05
# Score: 5.470162868499756
# Trial summary
# Hyperparameters:
# hidden_layers: 50, 100, 100
# learning_rate: 0.05
# Score: 13.247005462646484
# Trial summary
# Hyperparameters:
# hidden_layers: 50, 500, 50
# learning_rate: 0.05
# Score: 148.91970825195312
# Trial summary
# Hyperparameters:
# hidden_layers: 1000, 50
# learning_rate: 0.05
# Score: 380.2320556640625
# ExecutionResult(
#     component_id: Tuner
#     execution_id: 6
#     outputs:
#         best_hyperparameters: Channel(
#             type_name: HyperParameters
#             artifacts: [Artifact(artifact: id: 13
#         type_id: 25
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Tuner/best_hyperparameters/6"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "best_hyperparameters"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Tuner"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 25
#         name: "HyperParameters"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
from tfx.components import Trainer

trainer = Trainer(
    module_file=_module_file,
    examples=transform.outputs['transformed_examples'],
    transform_graph=transform.outputs['transform_graph'],
    schema=schema_gen.outputs['schema'],
    train_args=trainer_pb2.TrainArgs(num_steps=10000),
    eval_args=trainer_pb2.EvalArgs(num_steps=5000)
)

context.run(trainer)

model_dir = trainer.outputs['model_run'].get()[0].uri

# %load_ext tensorboard
# %tensorboard --logdir {model_dir}
# Out:
# /home/renaud/.cache/pypoetry/virtualenvs/covid-train-lO3GTi_V-py3.8/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# running bdist_wheel
# running build
# running build_py
# installing to /tmp/tmpk1gwbzt2
# running install
# running install_lib
# copying build/lib/prepare_data_utils.py -> /tmp/tmpk1gwbzt2
# copying build/lib/covid_train_dag.py -> /tmp/tmpk1gwbzt2
# copying build/lib/prepare_data_dag.py -> /tmp/tmpk1gwbzt2
# copying build/lib/covid_train_utils.py -> /tmp/tmpk1gwbzt2
# running install_egg_info
# running egg_info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# running install_scripts
# creating /tmp/tmpk1gwbzt2/tfx_user_code_Trainer-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/WHEEL
# creating '/tmp/tmp5jgfdp5i/tfx_user_code_Trainer-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca-py3-none-any.whl' and adding '/tmp/tmpk1gwbzt2' to it
# adding 'covid_train_dag.py'
# adding 'covid_train_utils.py'
# adding 'prepare_data_dag.py'
# adding 'prepare_data_utils.py'
# adding 'tfx_user_code_Trainer-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca.dist-info/RECORD'
# removing /tmp/tmpk1gwbzt2
# Processing /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/_wheels/tfx_user_code_Trainer-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca-py3-none-any.whl
# Installing collected packages: tfx-user-code-Trainer
# Successfully installed tfx-user-code-Trainer-0.0+bba14451182d58fb4bafcf7a588fcb8f3e67cbd21fe511dede6d1df57195a7ca
# 10000/10000 [==============================] - 25s 2ms/step - loss: 0.5430 - mean_squared_error: 0.5430 - val_loss: 0.4461 - val_mean_squared_error: 0.4461
# Tensor("Sub:0", shape=(None, 0), dtype=float32)
# INFO:tensorflow:Assets written to: /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Trainer/model/7/Format-Serving/assets
# INFO:tensorflow:Assets written to: /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Trainer/model/7/Format-Serving/assets
#       <iframe id="tensorboard-frame-7157025211bf9eeb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7157025211bf9eeb");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from tfx.dsl.experimental import latest_blessed_model_resolver
from tfx.dsl.components.common import resolver
from tfx.types import Channel
from tfx.types.standard_artifacts import Model
from tfx.types.standard_artifacts import ModelBlessing

model_resolver = resolver.Resolver(
    strategy_class=latest_blessed_model_resolver.LatestBlessedModelResolver,
    model=Channel(type=Model),
    model_blessing=Channel(
        type=ModelBlessing)
).with_id('latest_blessed_model_resolver')

context.run(model_resolver)
# Out:
# ExecutionResult(
#     component_id: latest_blessed_model_resolver
#     execution_id: 8
#     outputs:
#         model: Channel(
#             type_name: Model
#             artifacts: []
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         model_blessing: Channel(
#             type_name: ModelBlessing
#             artifacts: []
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
from covid_train_utils import eval_config
from tfx.components import Evaluator
import tensorflow_model_analysis as tfma 

evaluator = Evaluator(
   examples=example_gen.outputs['examples'],
   model=trainer.outputs['model'],
   baseline_model=model_resolver.outputs['model'],
   eval_config=eval_config)
context.run(evaluator)

context.show(evaluator.outputs['evaluation'])

import tensorflow_model_analysis as tfma

# Get the TFMA output result path and load the result.
PATH_TO_RESULT = evaluator.outputs['evaluation'].get()[0].uri
tfma_result = tfma.load_eval_result(PATH_TO_RESULT)

# Show data sliced along feature column trip_start_hour.
tfma.view.render_slicing_metrics(tfma_result, slicing_column='region')
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc2da54f970> and <keras.engine.input_layer.InputLayer object at 0x7fc25ca63f70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc2da54f970> and <keras.engine.input_layer.InputLayer object at 0x7fc25ca63f70>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc2e3a7eac0> and <keras.engine.input_layer.InputLayer object at 0x7fc1f301d130>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc2e3a7eac0> and <keras.engine.input_layer.InputLayer object at 0x7fc1f301d130>).
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc25c2dbbe0> and <keras.engine.input_layer.InputLayer object at 0x7fc25c825bb0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc25c2dbbe0> and <keras.engine.input_layer.InputLayer object at 0x7fc25c825bb0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc2e00ffdc0> and <keras.engine.input_layer.InputLayer object at 0x7fc2e055f760>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc2e00ffdc0> and <keras.engine.input_layer.InputLayer object at 0x7fc2e055f760>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc25cd55280> and <keras.engine.input_layer.InputLayer object at 0x7fc1f3823280>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc25cd55280> and <keras.engine.input_layer.InputLayer object at 0x7fc1f3823280>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc3502a42b0> and <keras.engine.input_layer.InputLayer object at 0x7fc2e010b6d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc3502a42b0> and <keras.engine.input_layer.InputLayer object at 0x7fc2e010b6d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc25c5ccd30> and <keras.engine.input_layer.InputLayer object at 0x7fc20e41df10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc25c5ccd30> and <keras.engine.input_layer.InputLayer object at 0x7fc20e41df10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc20e38d4c0> and <keras.engine.input_layer.InputLayer object at 0x7fc20e6425b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fc20e38d4c0> and <keras.engine.input_layer.InputLayer object at 0x7fc20e6425b0>).
# WARNING:tensorflow:From /home/renaud/.cache/pypoetry/virtualenvs/covid-train-lO3GTi_V-py3.8/lib/python3.8/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:109: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/renaud/.cache/pypoetry/virtualenvs/covid-train-lO3GTi_V-py3.8/lib/python3.8/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:109: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# <b>Artifact at /tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Evaluator/evaluation/9</b><br/><br/>
# SlicingMetricsViewer(config={'weightedExamplesColumn': 'example_count'}, data=[{'slice': 'region:SUB-SAHARAN A…

# %%
from tfx.components import InfraValidator
from tfx.v1.proto import LocalDockerConfig, TensorFlowServing, ServingSpec, RequestSpec, TensorFlowServingRequestSpec

infra_validator = InfraValidator(
    model=trainer.outputs['model'],
    examples=example_gen.outputs['examples'],
    serving_spec=ServingSpec(
        tensorflow_serving=TensorFlowServing(tags=['latest']),
        local_docker=LocalDockerConfig()
    ),
    request_spec=RequestSpec(
        tensorflow_serving=TensorFlowServingRequestSpec(),
        make_warmup=True
    )
)

context.run(infra_validator)
# Out:
# ExecutionResult(
#     component_id: InfraValidator
#     execution_id: 10
#     outputs:
#         blessing: Channel(
#             type_name: InfraBlessing
#             artifacts: [Artifact(artifact: id: 18
#         type_id: 34
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/InfraValidator/blessing/10"
#         custom_properties {
#           key: "blessed"
#           value {
#             int_value: 1
#           }
#         }
#         custom_properties {
#           key: "has_model"
#           value {
#             int_value: 1
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "blessing"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "InfraValidator"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 34
#         name: "InfraBlessing"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
from tfx.components import Pusher
from tfx.v1.proto import PushDestination

pusher = Pusher(
  model=trainer.outputs['model'],
  #model_blessing=evaluator.outputs['blessing'],
  infra_blessing=infra_validator.outputs['blessing'],
  push_destination=PushDestination(
    filesystem=PushDestination.Filesystem(
        base_directory=_saved_models)
  )
)

context.run(pusher)
# Out:
# ExecutionResult(
#     component_id: Pusher
#     execution_id: 11
#     outputs:
#         pushed_model: Channel(
#             type_name: PushedModel
#             artifacts: [Artifact(artifact: id: 19
#         type_id: 36
#         uri: "/tmp/tfx-interactive-2022-02-25T14_33_23.032289-7v5t7po6/Pusher/pushed_model/11"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "pushed_model"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Pusher"
#           }
#         }
#         custom_properties {
#           key: "pushed"
#           value {
#             int_value: 1
#           }
#         }
#         custom_properties {
#           key: "pushed_destination"
#           value {
#             string_value: "/mnt/d/projects/covid-train/src/covid/../../saved_models/1645796233"
#           }
#         }
#         custom_properties {
#           key: "pushed_version"
#           value {
#             string_value: "1645796233"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 36
#         name: "PushedModel"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))
